# %%
import numpy as np
import matplotlib.pyplot as plt

# This is similar to the code from lecture 1
# to sample from a 2D Gaussian Distribution
mean = [0,2]
cov = [[1, 2], [2, 5]]
# Fix random seed to get consistent results
np.random.seed(1024)
X = np.random.multivariate_normal(mean, cov, 1000)
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
fig.show()
# Out:
# /var/folders/mw/szm2lqqj3y93njkycm32c6hw0000gn/T/ipykernel_16631/127763238.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# TODO: Report the estimate mean and covariance
# of the sampled points
print(f'mean of X: {np.mean(X, axis = 0)}')
print(f'covariance of X: {np.cov(X[:, 0], X[:, 1])}')
# Out:
# mean of X: [0.01909265 2.06052385]
# covariance of X: [[1.03589238 2.06244165]
#  [2.06244165 5.08839176]]

# %%
# TODO: Plot the histogram for the x-coordinates of X
# and y-coordinates of X respectively.
# You can use the plt.hist() function
x = X[:, 0]
plt.subplot(1, 2, 1)
plt.hist(x, weights = np.ones_like(x) / len(x))
#plt.title('histogram of x-coordinates of X')
plt.xlabel('x')
plt.ylabel('frequency')

y = X[:, 1]
plt.subplot(1, 2, 2)
plt.hist(y, weights = np.ones_like(y) / len(y))
#plt.title('histogram of y-coordinates of X')
plt.xlabel('y')
plt.ylabel('frequency')

plt.show()

# %%
# TODO: Are the x-coordinates of X samples from
# some Gaussian distribution?
# If so, estimate the mean and variance.
# Do the same for the y-coordinates.
x_mean = np.mean(X[:, 0])
x_var = np.var(X[:, 0])
x_std = np.std(X[:, 0])
print(f'mean of x: {x_mean}')
print(f'variance of x: {x_var}')
print(f'standard deviation of x: {x_std}')

y_mean = np.mean(X[:, 1])
y_var = np.var(X[:, 1])
y_std = np.std(X[:, 1])
print(f'mean of y: {y_mean}')
print(f'variance of y: {y_var}')
print(f'standard deviation of y: {y_std}')

# TODO: Generate a new 2D scatter plot of 1000 points,
# such that the x-coordinates(y-coordinates) of all the points
# are samples from a 1D Gaussian distribution 
# using the estimated mean and variance based on the x-coordinates(y-coordinates) of X.
x = np.random.randn(1000) * x_std + x_mean
y = np.random.randn(1000) * y_std + y_mean
plt.scatter(x, y)
plt.grid()
plt.show()
# Out:
# mean of x: 0.019092651459051667
# variance of x: 1.0348564864741474
# standard deviation of x: 1.0172789619736307
# mean of y: 2.0605238541899022
# variance of y: 5.083303371449156
# standard deviation of y: 2.2546182318630255

# %%
# Back to the original X
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])

# TODO: Plot a line segment with x = [-10, 10]
# and y = 3x + 1 onto the 2D-Gaussian plot.
# The np.linspace() function may be helpful.
x_space = np.linspace(-10, 10, 100)
y_space = x_space * 3 + 1
ax.plot(x_space, y_space)

fig.show()
# Out:
# /var/folders/mw/szm2lqqj3y93njkycm32c6hw0000gn/T/ipykernel_16631/2952990104.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# TODO: Project X onto line y=2x + 2
# and plot the projected points on the 2D space.
# You need to remove this line and assign the projected points to X_proj
X_proj = np.array([[y + x / 2 - 2, 2 * y + x + 1] for x, y in zip(X[:, 0], X[:, 1])]) / 2.5
x_space = np.linspace(-10, 10, 100)
y_space = x_space * 2 + 2
print(X_proj.shape)

# Here we only plot 30 points to check the correctness
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(x_space, y_space, linewidth = '0.5')
ax.scatter(X_proj[:30,0], X_proj[:30,1], c='b', s=10.0, alpha=1.0, label="Projected 2D-Gaussian")
ax.scatter(X[:30,0], X[:30,1], c='r', s=10.0, alpha=1.0, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
# You can also add the line from the previous plot for verification.
fig.show()
# Out:
# (1000, 2)
# /var/folders/mw/szm2lqqj3y93njkycm32c6hw0000gn/T/ipykernel_16631/4046900233.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# TODO: Draw the histogram of the x-coordinates
# of the projected points.
# Are the x-coordinates of the projected points
# samples from some Gaussian distribution?
# If so, estimate the mean and variance.

plt.hist(X_proj[:, 0])
plt.show()

print(f'mean of projected x: {np.mean(X_proj[:, 0])}')
print(f'variance of projected x: {np.var(X_proj[:, 0])}')
# Out:
# mean of projected x: 0.028028071967771222
# variance of projected x: 1.1843834728271618
